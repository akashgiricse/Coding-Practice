# %%
require 'httparty'
require 'hypertrack'
HyperTrack.secret_key = "<secret_key_here>"
HyperTrack.api_version = "v2"

# Get all data related to deliveries which are completed
# =====================================
1.upto(14) do |page_no|
  response = HTTParty.get("https://api.hypertrack.com/api/v2/actions/?page=#{page_no}&status=completed", :headers => { "Authorization" => "Token #{HyperTrack.secret_key}" }, format: :plain)
  1.upto(8) do |i|
    delivery_id = JSON.parse(response.body)["results"][i]["unique_id"]
    name = JSON.parse(response.body)["results"][i]["user"]["name"]
    duration = JSON.parse(response.body)["results"][i]["duration"]
    distance = JSON.parse(response.body)["results"][i]["distance"]
    puts "delivery_id: #{delivery_id}"
    puts "name: #{name}"
    puts "duration: #{duration}"
    puts "distance: #{distance}"
    puts "-----------------"
  end
end

# =======================================

# function to get data related to a perticular delivery_id


# def get_delivery_details(delivery_id)
#   response = HTTParty.get("https://api.hypertrack.com/api/v2/actions/?unique_id=#{delivery_id}&status=completed", :headers => { "Authorization" => "Token #{HyperTrack.secret_key}" }, format: :plain)
#   name = JSON.parse(response.body)["results"][0]["user"]["name"]
#   duration = JSON.parse(response.body)["results"][0]["duration"]
#   distance = JSON.parse(response.body)["results"][0]["distance"]
#   puts name
#   puts duration
#   puts distance
# end

# get_delivery_details(57545)
# Out:
# delivery_id: 57544
# name: plaban
# duration: 900
# distance: 0
# -----------------
# delivery_id: 96802
# name: Ashok
# duration: 4639
# distance: 1411
# -----------------
# delivery_id: 96784
# name: Ashok
# duration: 7735
# distance: 0
# -----------------
# delivery_id: 88371
# name: Veer
# duration: 30
# distance: 0
# -----------------
# delivery_id: 96364
# name: Ramesh
# duration: 78
# distance: 0
# -----------------
# delivery_id: 57224
# name: Veere
# duration: 3
# distance: 0
# -----------------
# delivery_id: 57164
# name: Veere
# duration: 5967
# distance: 73
# -----------------
# delivery_id: 57189
# name: Veere
# duration: 5280
# distance: 15
# -----------------
# delivery_id: 57354
# name: Sathish
# duration: 390
# distance: 0
# -----------------
# delivery_id: 57355
# name: Sathish
# duration: 79186
# distance: 22139
# -----------------
# delivery_id: 57223
# name: Veere
# duration: 18350
# distance: 8705
# -----------------
# delivery_id: 57318
# name: Veere
# duration: 2
# distance: 0
# -----------------
# delivery_id: 57289
# name: Veere
# duration: 244
# distance:
# -----------------
# delivery_id: 57163
# name: Veere
# duration: 66454
# distance: 5271
# -----------------
# delivery_id: 57222
# name: Veere
# duration: 2592166
# distance: 132
# -----------------
# delivery_id: 56604
# name: Veere
# duration: -2588606
# distance: 0
# -----------------
# delivery_id: -L8lMoxvNWMhNBmYcVRF
# name: Ramu
# duration: 21
# distance: 0
# -----------------
# delivery_id: -L8lMoxvNWMhNBmYcVRD
# name: Ramu
# duration: 21
# distance: 0
# -----------------
# delivery_id: -L8CLberyXxBTKpXcLvA
# name: Zoro
# duration: 33
# distance: 0
# -----------------
# delivery_id: -L8CLberyXxBTKpXcLvC
# name: Zoro
# duration: 51
# distance: 0
# -----------------
# delivery_id: -L5TKOhF4UB2Zs3zAMbi
# name: Bazzi
# duration: 45
# distance: 0
# -----------------
# delivery_id: -L5TKOhDipAzQOZNuBEd
# name: Veer
# duration: 404
# distance: 0
# -----------------
# delivery_id: -L7iauwrKcNqAHBeSDH9
# name: Veer
# duration: 426
# distance: 0
# -----------------
# delivery_id: -L2icDCj_aQXWDVTxtcm
# name: Veer
# duration: 527
# distance: 0
# -----------------
# delivery_id: -L7iauwqY2oKQfhFSd9k
# name: Veer
# duration: 93
# distance: 0
# -----------------
# delivery_id: -L2icDCj_aQXWDVTxtcf
# name: Veer
# duration: 132
# distance: 0
# -----------------
# delivery_id: -L2icDCj_aQXWDVTxtcg
# name: Veer
# duration: 145
# distance: 0
# -----------------
# delivery_id: -L5TKOhDipAzQOZNuBES
# name: Veer
# duration: 9
# distance: 0
# -----------------
# delivery_id: -L7iauwpe8wo_euMTPKt
# name: Y2K
# duration: 915
# distance: 12
# -----------------
# delivery_id: -L2icDCj_aQXWDVTxtcb
# name: Veer
# duration: 8924
# distance: 0
# -----------------
# delivery_id: -L5TKOhCBcWHPURJkWJm
# name: Veer
# duration: 478
# distance: 0
# -----------------
# delivery_id: -L-HAtJHV5v5YvEs5TqO
# name: Veer
# duration: 49
# distance: 0
# -----------------
# delivery_id: -L5ObOhCzip1Bv_jbpbn
# name: Veer
# duration: 30
# distance: 0
# -----------------
# delivery_id: -L2icDCWNeA6fmqT9003
# name: Veer
# duration: 4
# distance: 0
# -----------------
# delivery_id: -L2iPV8YmSClMS3NlD6D
# name: Veer
# duration: 5
# distance: 0
# -----------------
# delivery_id: -L1vlPawwenPeLgjkEq8
# name: Veer
# duration: 498
# distance: 0
# -----------------
# delivery_id: -L2iP1A1Cd9hmcAddk_l
# name: Veer
# duration: 10
# distance: 0
# -----------------
# delivery_id: -L2icDCWNeA6fmqT900-
# name: Veer
# duration: 15
# distance: 0
# -----------------
# delivery_id: -L2ial25wWvJbVYivy3j
# name: Veer
# duration: 10
# distance: 0
# -----------------
# delivery_id: -L2eC2Rmjvm-pdaoJc5R
# name: Veer
# duration: 4
# distance: 0
# -----------------
# delivery_id: -L2ial25wWvJbVYivy3i
# name: Veer
# duration: 137
# distance: 0
# -----------------
# delivery_id: -L2iPV8Xam-OmLt_oPYT
# name: Veer
# duration: 14
# distance: 0
# -----------------
# delivery_id: -L2eC2Rmjvm-pdaoJc5S
# name: Veer
# duration: 3621
# distance: 0
# -----------------
# delivery_id: -L1vlPawwenPeLgjkEq7
# name: Veer
# duration: 43
# distance: 0
# -----------------
# delivery_id: -L2eC2Rmjvm-pdaoJc5Q
# name: Veer
# duration: 76
# distance: 0
# -----------------
# delivery_id: -L0EI6f8pi2PJSR7T4ab
# name: Veer
# duration:
# distance: 0
# -----------------
# delivery_id: -L0TQLZpiKPDzII3TgIi
# name: Veer
# duration:
# distance: 17
# -----------------
# delivery_id: -L0EBdwpX_gYsqYPm3F7
# name: Veer
# duration:
# distance: 18
# -----------------
# delivery_id: -L0EY1x65bO0d0-ELiWQ
# name: Plaban
# duration:
# distance: 13
# -----------------
# delivery_id: -L0EI6f8pi2PJSR7T4aJ
# name: Veer
# duration:
# distance: 18825
# -----------------
# delivery_id: -L0EBdwpX_gYsqYPm3Ew
# name: Plaban
# duration:
# distance: 0
# -----------------
# delivery_id: -L0EY1x5-guIajBSuxdK
# name: Plaban
# duration:
# distance: 0
# -----------------
# delivery_id: -L0EI6f8pi2PJSR7T4aF
# name: Veer
# duration:
# distance: 11747
# -----------------
# delivery_id: -L-LB9LBf0aVwQ__UI7Q
# name: Veer
# duration:
# distance: 16
# -----------------
# delivery_id: -L0EERtgH1VwXAyGnMLz
# name: Veer
# duration:
# distance: 21
# -----------------
# delivery_id: -L0EY1x5-guIajBSuxdC
# name: Plaban
# duration:
# distance: 1
# -----------------
# delivery_id: -L0EI6f7fBIHtf4rpcbK
# name: Plaban
# duration:
# distance: 18
# -----------------
# delivery_id: -L0EERtgH1VwXAyGnMLv
# name: Veer
# duration:
# distance: 18
# -----------------
# delivery_id: -L0EERtgH1VwXAyGnMLu
# name: Veer
# duration:
# distance: 18
# -----------------
# delivery_id: -L0EDaQouZ2LdiO5aClN
# name: Veer
# duration:
# distance: 43
# -----------------
# delivery_id: -L0EBdwo2ariJ1zwjsnb
# name: Veer
# duration:
# distance: 33
# -----------------
# delivery_id: -L0EBdwo2ariJ1zwjsnd
# name: Veer
# duration:
# distance: 33
# -----------------
# delivery_id: -L-oymeeTMTjMy12sFDw
# name: Veer
# duration:
# distance: 0
# -----------------
# delivery_id: -Kw9LPssZ3AMccOYtMtD
# name: Veer
# duration:
# distance: 0
# -----------------
# NoMethodError: undefined method `[]' for nil:NilClass
# <main>:10:in `block (2 levels) in <main>'
# <main>:9:in `upto'
# <main>:9:in `block in <main>'
# <main>:7:in `upto'
# <main>:7:in `<main>'
# /home/rango/.rvm/gems/ruby-2.3.1@ruby2.3.1rails4.2.4/gems/iruby-0.3/lib/iruby/backend.rb:44:in `eval'
# /home/rango/.rvm/gems/ruby-2.3.1@ruby2.3.1rails4.2.4/gems/iruby-0.3/lib/iruby/backend.rb:44:in `eval'
# /home/rango/.rvm/gems/ruby-2.3.1@ruby2.3.1rails4.2.4/gems/iruby-0.3/lib/iruby/backend.rb:12:in `eval'
# /home/rango/.rvm/gems/ruby-2.3.1@ruby2.3.1rails4.2.4/gems/iruby-0.3/lib/iruby/kernel.rb:87:in `execute_request'
# /home/rango/.rvm/gems/ruby-2.3.1@ruby2.3.1rails4.2.4/gems/iruby-0.3/lib/iruby/kernel.rb:47:in `dispatch'
# /home/rango/.rvm/gems/ruby-2.3.1@ruby2.3.1rails4.2.4/gems/iruby-0.3/lib/iruby/kernel.rb:37:in `run'
# /home/rango/.rvm/gems/ruby-2.3.1@ruby2.3.1rails4.2.4/gems/iruby-0.3/lib/iruby/command.rb:70:in `run_kernel'
# /home/rango/.rvm/gems/ruby-2.3.1@ruby2.3.1rails4.2.4/gems/iruby-0.3/lib/iruby/command.rb:34:in `run'
# /home/rango/.rvm/gems/ruby-2.3.1@ruby2.3.1rails4.2.4/gems/iruby-0.3/bin/iruby:5:in `<top (required)>'
# /home/rango/.rvm/gems/ruby-2.4.1/bin/iruby:23:in `load'
# /home/rango/.rvm/gems/ruby-2.4.1/bin/iruby:23:in `<main>'
# /home/rango/.rvm/gems/ruby-2.3.1@ruby2.3.1rails4.2.4/bin/ruby_executable_hooks:15:in `eval'
# /home/rango/.rvm/gems/ruby-2.3.1@ruby2.3.1rails4.2.4/bin/ruby_executable_hooks:15:in `<main>'
